# %% [markdown]
# Connected to base (Python 3.9.24)

# %%
from liquidbased_quantification import LiquidQuantifier

# The D_R and AerationFieldSize parameters can be adjusted based on specific site conditions
model = LiquidQuantifier("data/Monitoring_Data_Example.xlsx", D_R = 7.55, AerationFieldSize = 462.0)

results = model.run_pipeline(show_plots=True)
print(results.head())
results.to_excel("liquid_quantification_results.xlsx", index=False)
# Out:
#                      RawAirflow  RawLiqN2O  RawLiqTemp  After_IQR_Airflow  \
# 2025-02-06 00:00:00    0.418898   0.041505   26.431015                NaN
# 2025-02-06 00:01:00    0.389170   0.041460   26.430177            0.38917
# 2025-02-06 00:02:00    0.389170   0.041454   26.429853            0.38917
# 2025-02-06 00:03:00    0.389170   0.041549   26.429546            0.38917
# 2025-02-06 00:04:00    0.393030   0.041578   26.429240            0.39303
#
#                      After_IQR_LiqN2O  After_IQR_LiqTemp  After_inter_Airflow  \
# 2025-02-06 00:00:00          0.041505          26.431015                  NaN
# 2025-02-06 00:01:00          0.041460          26.430177              0.38917
# 2025-02-06 00:02:00          0.041454          26.429853              0.38917
# 2025-02-06 00:03:00          0.041549          26.429546              0.38917
# 2025-02-06 00:04:00          0.041578          26.429240              0.39303
#
#                      After_inter_LiqN2O  After_inter_LiqTemp    kla_SFV  \
# 2025-02-06 00:00:00            0.041505            26.431015        NaN
# 2025-02-06 00:01:00            0.041460            26.430177  30.637285
# 2025-02-06 00:02:00            0.041454            26.429853  30.637050
# 2025-02-06 00:03:00            0.041549            26.429546  30.636827
# 2025-02-06 00:04:00            0.041578            26.429240  30.897808
#
#                      EstimatedFlux
# 2025-02-06 00:00:00            NaN
# 2025-02-06 00:01:00       0.180542
# 2025-02-06 00:02:00       0.180513
# 2025-02-06 00:03:00       0.180926
# 2025-02-06 00:04:00       0.182760
